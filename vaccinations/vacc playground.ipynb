# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
df = pd.read_csv('country_vaccinations.csv')
df
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 4903  Zimbabwe      ZWE  2021-02-26             12579.0            12579.0
# 4904  Zimbabwe      ZWE  2021-02-27             15705.0            15705.0
# 4905  Zimbabwe      ZWE  2021-02-28             18843.0            18843.0
# 4906  Zimbabwe      ZWE  2021-03-01             21456.0            21456.0
# 4907  Zimbabwe      ZWE  2021-03-02             25077.0            25077.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4908 non-null   object
#  1   iso_code                             4592 non-null   object
#  2   date                                 4908 non-null   object
#  3   total_vaccinations                   3193 non-null   float64
#  4   people_vaccinated                    2718 non-null   float64
#  5   people_fully_vaccinated              1845 non-null   float64
#  6   daily_vaccinations_raw               2694 non-null   float64
#  7   daily_vaccinations                   4748 non-null   float64
#  8   total_vaccinations_per_hundred       3193 non-null   float64
#  9   people_vaccinated_per_hundred        2718 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1845 non-null   float64
# ...

# %%
df['date']
# Out:
# 0       2021-01-10
# 1       2021-01-11
# 2       2021-01-12
# 3       2021-01-13
# 4       2021-01-14
#            ...
# 4903    2021-02-26
# 4904    2021-02-27
# 4905    2021-02-28
# 4906    2021-03-01
# 4907    2021-03-02
# Name: date, Length: 4908, dtype: object

# %%
df['country'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Anguilla', 'Argentina',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Bermuda', 'Bolivia', 'Brazil',
#        'Bulgaria', 'Cambodia', 'Canada', 'Cayman Islands', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'England', 'Estonia', 'Faeroe Islands', 'Falkland Islands',
#        'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Greenland',
#        'Guatemala', 'Guernsey', 'Guyana', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Japan', 'Jersey', 'Jordan',
#        'Kazakhstan', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Macao', 'Malaysia', 'Maldives',
# ...

# %%
f = plt.figure(figsize=(70, 10))
sb.catplot(y = "country", data = df, kind = "count")

# %%
for v in df['vaccines'].unique():
    print(v)
    print(df[df['vaccines'] == v]['country'].unique())
    print()
# Out:
# Pfizer/BioNTech
# ['Albania' 'Andorra' 'Australia' 'Bermuda' 'Cayman Islands' 'Colombia'
#  'Costa Rica' 'Croatia' 'Cyprus' 'Ecuador' 'Faeroe Islands' 'Gibraltar'
#  'Greenland' 'Guernsey' 'Japan' 'Kuwait' 'Lebanon' 'Malta' 'Monaco'
#  'New Zealand' 'Panama' 'Qatar' 'Singapore' 'Slovakia'
#  'Turks and Caicos Islands']
#
# Sputnik V
# ['Algeria' 'Argentina' 'Belarus' 'Bolivia' 'Iran' 'Kazakhstan'
#  'Montenegro' 'Paraguay' 'San Marino' 'Venezuela']
#
# Oxford/AstraZeneca
# ['Anguilla' 'Bangladesh' 'Barbados' 'Dominican Republic' 'El Salvador'
#  'Falkland Islands' 'Guyana' 'Maldives' 'Mauritius' 'Mongolia'
#  'Montserrat' 'Myanmar' 'Nepal' 'Saint Helena' 'South Korea' 'Sri Lanka'
#  'Trinidad and Tobago' 'Ukraine']
#
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# ['Austria' 'Belgium' 'Bulgaria' 'Czechia' 'Estonia' 'Finland' 'France'
#  'Germany' 'Greece' 'Iceland' 'Ireland' 'Italy' 'Latvia' 'Lithuania'
#  'Luxembourg' 'Netherlands' 'Norway' 'Poland' 'Romania' 'Spain']
#
# ...

# %% [markdown]
# #  England

# %%
# extract country
uk = pd.DataFrame(df[df['country'] == 'England'])
uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 1416 to 1494
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              79 non-null     object
#  1   iso_code                             0 non-null      object
#  2   date                                 79 non-null     object
#  3   total_vaccinations                   55 non-null     float64
#  4   people_vaccinated                    55 non-null     float64
#  5   people_fully_vaccinated              52 non-null     float64
#  6   daily_vaccinations_raw               50 non-null     float64
#  7   daily_vaccinations                   78 non-null     float64
#  8   total_vaccinations_per_hundred       55 non-null     float64
#  9   people_vaccinated_per_hundred        55 non-null     float64
#  10  people_fully_vaccinated_per_hundred  52 non-null     float64
# ...

# %%
# extract country
sg = pd.DataFrame(df[df['country'] == 'Singapore'])
sg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 4117 to 4166
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              50 non-null     object
#  1   iso_code                             50 non-null     object
#  2   date                                 50 non-null     object
#  3   total_vaccinations                   9 non-null      float64
#  4   people_vaccinated                    9 non-null      float64
#  5   people_fully_vaccinated              6 non-null      float64
#  6   daily_vaccinations_raw               1 non-null      float64
#  7   daily_vaccinations                   49 non-null     float64
#  8   total_vaccinations_per_hundred       9 non-null      float64
#  9   people_vaccinated_per_hundred        9 non-null      float64
#  10  people_fully_vaccinated_per_hundred  6 non-null      float64
# ...

# %%
print(uk['date'].min())
print(uk['date'].max())
# Out:
# 2020-12-13
# 2021-03-01

# %%
f = plt.figure(figsize=(16,16))
uk["date"] = pd.to_datetime( .Date)
sb.lineplot(x="date", y="total_vaccinations", data=uk)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-e4699a67ea37> in <module>
#       1 f = plt.figure(figsize=(16,16))
# ----> 2 uk["date"] = pd.to_datetime(uk.Date)
#       3 sb.lineplot(x="date", y="total_vaccinations", data=uk)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
f = plt.figure(figsize=(16,16))
sb.lineplot(x="date", y="people_vaccinated", data=uk)
# Out:
# <AxesSubplot:xlabel='date', ylabel='people_vaccinated'>

# %%
f = plt.figure(figsize=(16,16))
sb.lineplot(x="date", y="people_fully_vaccinated", data=uk)
# Out:
# <AxesSubplot:xlabel='date', ylabel='people_fully_vaccinated'>

# %%
f = plt.figure(figsize=(16,16))
sb.lineplot(x="date", y="daily_vaccinations_raw", data=uk)
# Out:
# <AxesSubplot:xlabel='date', ylabel='daily_vaccinations_raw'>

# %%
f = plt.figure(figsize=(16,16))
sb.lineplot(x="date", y="daily_vaccinations", data=uk)
# Out:
# <AxesSubplot:xlabel='date', ylabel='daily_vaccinations'>

# %%
uk
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 1416  England      NaN  2020-12-13             55467.0            55467.0
# 1417  England      NaN  2020-12-14                 NaN                NaN
# 1418  England      NaN  2020-12-15                 NaN                NaN
# 1419  England      NaN  2020-12-16                 NaN                NaN
# 1420  England      NaN  2020-12-17                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 1490  England      NaN  2021-02-25          16785841.0         16227104.0
# 1491  England      NaN  2021-02-26          17254844.0         16679881.0
# 1492  England      NaN  2021-02-27          17641792.0         17051245.0
# 1493  England      NaN  2021-02-28          17812739.0         17212804.0
# 1494  England      NaN  2021-03-01          17985951.0         17373384.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
tv = pd.DataFrame(df[df['total_vaccinations'].isnull() == False])
tv
# Out:
#                country iso_code        date  total_vaccinations  \
# 2719         Lithuania      LTU  2020-12-08                 1.0
# 3244  Northern Ireland      NaN  2020-12-13              3623.0
# 3924          Scotland      NaN  2020-12-13             19008.0
# 1416           England      NaN  2020-12-13             55467.0
# 4816             Wales      NaN  2020-12-13              8239.0
# ...                ...      ...         ...                 ...
# 2150             India      IND  2021-03-02          15620749.0
# 2103           Iceland      ISL  2021-03-02             33835.0
# 4809           Uruguay      URY  2021-03-02             27630.0
# 2384            Israel      ISR  2021-03-02           8315288.0
# 4907          Zimbabwe      ZWE  2021-03-02             25077.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 2719                1.0                      NaN                     NaN
# ...
